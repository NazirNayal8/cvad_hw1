# %%
import os
os.chdir('../')

# %%
os.getcwd()
# Out:
# '/home/nazirnayal/Documents/courses/CV_AV/HW1/cvad_hw1'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.figure_factory as ff
import pandas as pd
import cv2
from expert_dataset import ExpertDataset

# %%
dataset = ExpertDataset(data_root='/media/nazirnayal/DATA/datasets/Carla/expert_data/train')

# %%
img, v, c, actions = dataset[0]

# %%
plt.imshow(img.permute(1, 2, 0))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
data = pd.DataFrame()

# %%
data['speeds'] = dataset.speeds
data['commands'] = dataset.commands
data['throttle'] = dataset.actions[:, 0]
data['steer'] = dataset.actions[:, 1]
data['break'] = dataset.actions[:, 2]

# %%
# fig = ff.create_distplot([data['throttle']], ['throttle'], bin_size=0.01)

# fig.show()

# %%
plt.figure(figsize=(8, 5))
fig = data['speeds'].hist(log=True, bins=100)
plt.xlabel('Speed')
plt.ylabel('Log Frequency')
plt.title('Speed Log Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 5))
fig = data['commands'].astype(np.int32).hist(log=True)
plt.xlabel('Commands')
plt.ylabel('Log Frequency')
plt.title('Commands Log Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 5))
fig = data['throttle'].hist(log=True, bins=100)
plt.xlabel('Throttle')
plt.ylabel('Log Frequency')
plt.title('Throttle Log Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 5))
fig = data['steer'].hist(log=True, bins=100)
plt.xlabel('Steer')
plt.ylabel('Log Frequency')
plt.title('Steer Log Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 5))
fig = data['break'].hist(log=True, bins=100)
plt.xlabel('Brake')
plt.ylabel('Log Frequency')
plt.title('Brake Log Distribution')
plt.show()

# %%
img, _, _, _ = dataset[0]

# %%
image = cv2.cvtColor(cv2.imread(dataset.images[0]), cv2.COLOR_BGR2RGB).astype(np.float32)

# %%
import random

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 4, 12, 16, 44, 40, 334029)

# %%
random.randint(0, 1000)

# %% [markdown]
# # Analyzing Affordances

# %%
dataset_aff = ExpertDataset(data_root='/media/nazirnayal/DATA/datasets/Carla/expert_data/train', 
                            mode='affordances')

# %%
img, lane_dist, route_angle, tl_dist, tl_state = dataset_aff[0]

# %%
plt.imshow(img.permute(1, 2, 0))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
lane_dist, route_angle, tl_dist, tl_state
# Out:
# (tensor(0.4057), tensor(-0.0452), tensor(45.), tensor(0, dtype=torch.int8))
